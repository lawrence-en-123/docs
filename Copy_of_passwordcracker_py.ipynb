# %% [markdown]
# <a href="https://colab.research.google.com/github/lawrence-en-123/docs/blob/main/Copy_of_passwordcracker_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
import os
u_pwd = ['a','b','c','d','e','f','g','h','i','j','k','1','2','3','4','5','6']

pw=""
_pwd = ''.join(u_pwd) # Assuming _pwd should be the whole u_pwd list converted to a string
while(pw!=_pwd):
    pw=""
    for letter in range(len(u_pwd)):
      guess_pwd = u_pwd[randint(0,len(u_pwd)-1)] # Fixed index out of range
      pw=str(guess_pwd)+str(pw)
      print(pw)
      print("cracking password...please wait!")
      os.system("cls") # This will only work on Windows
print("your password is :",pw)
from random import randint
import os
u_pwd = ['a','b','c','d','e','f','g','h','i','j','k','1','2','3','4','5','6']

pw=""
_pwd = ''.join(u_pwd) # Assuming _pwd should be the whole u_pwd list converted to a string
while(pw!=_pwd):
    pw=""
    for letter in range(len(u_pwd)):
      guess_pwd = u_pwd[randint(0,len(u_pwd)-1)] # Fixed index out of range
      pw=str(guess_pwd)+str(pw)
      print(pw)
      print("cracking password...please wait!")
      os.system("cls") # This will only work on Windows
print("your password is :",pw)

pw=""
while(pw!=_pwd):
    pw=""
    for letter in range(len(u_pwd)):
      guess_pwd = u_pwd[randint(0,len(u_pwd)-1)]
      pw=str(guess_pwd)+str(pw)
      print(pw)
      print("cracking password...please wait!")
      os.system("cls")
print("your password is :",pw)

# .LET'S.CRACK.IT!
# Out:
# Streaming output truncated to the last 5000 lines.
# hh3g5iej
# cracking password...please wait!
# 2hh3g5iej
# cracking password...please wait!
# c2hh3g5iej
# cracking password...please wait!
# 1c2hh3g5iej
# cracking password...please wait!
# j1c2hh3g5iej
# cracking password...please wait!
# 6j1c2hh3g5iej
# cracking password...please wait!
# k6j1c2hh3g5iej
# cracking password...please wait!
# kk6j1c2hh3g5iej
# cracking password...please wait!
# 5kk6j1c2hh3g5iej
# cracking password...please wait!
# 25kk6j1c2hh3g5iej
# cracking password...please wait!
# i
# cracking password...please wait!
# 4i
# cracking password...please wait!
# 54i
# cracking password...please wait!
# e54i
# cracking password...please wait!
# fe54i
# cracking password...please wait!
# dfe54i
# cracking password...please wait!
# hdfe54i
# cracking password...please wait!
# bhdfe54i
# cracking password...please wait!
# abhdfe54i
# cracking password...please wait!
# 6abhdfe54i
# cracking password...please wait!
# ...
